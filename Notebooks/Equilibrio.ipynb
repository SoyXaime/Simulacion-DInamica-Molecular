# %% [markdown]
# Gráficar datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leer el archivo de resultados
df = pd.read_csv("gname2.txt", delim_whitespace=True, header=None,
                 names=["tiempo", "Ep", "Ec", "E_total"])
df.head()
# Out:
#    tiempo        Ep        Ec   E_total
# 0    0.01 -1719.964  1054.930 -665.0335
# 1    0.02 -1722.069  1057.035 -665.0340
# 2    0.03 -1716.508  1051.476 -665.0314
# 3    0.04 -1709.286  1044.251 -665.0352
# 4    0.05 -1706.562  1041.529 -665.0332

# %%
# Graficar energía total
plt.plot(df["tiempo"], df["E_total"], label="Energía total")
#plt.plot(df["tiempo"], df["Ep"], label="Energía potencial")
#plt.plot(df["tiempo"], df["Ec"], label="Energía cinética")

plt.xlabel("Tiempo")
plt.ylabel("Energía total")
plt.title("Evolución de la energía en el tiempo")
plt.grid(True)
plt.minorticks_on()
#plt.legend()
plt.savefig("grafico4.png") 
plt.show()

# %%
# Graficar energía total
plt.plot(df["tiempo"], df["E_total"], label="Energía total")
plt.plot(df["tiempo"], df["Ep"], label="Energía potencial")
plt.plot(df["tiempo"], df["Ec"], label="Energía cinética")

plt.xlabel("Tiempo")
plt.ylabel("Energía")
plt.title("Evolución de la energía en el tiempo")
plt.grid(True)
plt.minorticks_on()
plt.legend()
